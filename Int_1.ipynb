# %% [markdown]
# <a href="https://colab.research.google.com/github/StudentWorkwithgit/Data-Analytics-Using-Python-Project-/blob/main/Int_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mark1=int(input ("Enter the mark1:"))
mark2=int (input ("Enter the mark2:"))
mark3=int(input ("Enter the mark3:"))
total=mark1+mark2+mark3
avg=total/3

print ("Total:", total)
print ("AVg",avg)

if avg>=50:
  print ("PASS")
else:
  print ("FAIL")
# Out:
# Enter the mark1:99
# Enter the mark2:45
# Enter the mark3:83
# Total: 227
# AVg 75.66666666666667
# PASS

# %%
def get_grade(mark):
      if mark >= 90:
           return "S"
             elif mark >= 75:
              return "A"
             else:
              return "F"

              students = {
                           "Asha": 95,
                           "Rahul": 82,
                            "Priya": 70,
                            "Kavin": 91,
                            "Meena": 65
                                                          }

                                                          passed = 0
                                                          failed = 0

                                                          print("Student Results")
                                                          print("-" * 30)

                                                          for name, mark in students.items():
                                                              grade = get_grade(mark)

                                                                  print(f"Name: {name}")
                                                                      print(f"Marks: {mark}")
                                                                          print(f"Grade: {grade}")
                                                                              print()

                                                                                  if grade == "F":
                                                                                          failed += 1
                                                                                              else:
                                                                                                      passed += 1

                                                                                                      print("-" * 30)
                                                                                                      print("Passed Students :", passed)
                                                                                                      print("Failed Students :", failed)
